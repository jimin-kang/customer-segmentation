# %% [markdown]
# CUSTOMER SEGMENTATION - CLUSTERING & PCA APPLICATION
#
# In this notebook, we will go over how to segment/cluster customers into different groups using K-means clustering. Once we have divided the customers into separate groups, we will use PCA to visualize the distinct clusters. The dataset we will be using is (artificial) data from a bank customer database containing 8950 customers and their credit card information. You can find the dataset here (https://www.kaggle.com/datasets/rruchi/marketing-datacsv).

# %% [markdown]
# First we install necessary packages - the kneed package will be used later in our clustering analysis

# %%
#INSTALL NECESSARY PACKAGES/LIBRARIES
# !pip install kneed
# !pip install fancyimpute
# Out:
# Requirement already satisfied: kneed in c:\users\jimin\anaconda3\lib\site-packages (0.8.1)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\jimin\anaconda3\lib\site-packages (from kneed) (1.7.1)
# Requirement already satisfied: numpy>=1.14.2 in c:\users\jimin\anaconda3\lib\site-packages (from kneed) (1.20.3)
# Requirement already satisfied: fancyimpute in c:\users\jimin\anaconda3\lib\site-packages (0.7.0)
# Requirement already satisfied: cvxpy in c:\users\jimin\anaconda3\lib\site-packages (from fancyimpute) (1.2.2)
# Requirement already satisfied: knnimpute>=0.1.0 in c:\users\jimin\anaconda3\lib\site-packages (from fancyimpute) (0.1.0)
# Requirement already satisfied: cvxopt in c:\users\jimin\anaconda3\lib\site-packages (from fancyimpute) (1.3.0)
# Requirement already satisfied: nose in c:\users\jimin\anaconda3\lib\site-packages (from fancyimpute) (1.3.7)
# Requirement already satisfied: scikit-learn>=0.24.2 in c:\users\jimin\anaconda3\lib\site-packages (from fancyimpute) (0.24.2)
# Requirement already satisfied: pytest in c:\users\jimin\anaconda3\lib\site-packages (from fancyimpute) (6.2.4)
# Requirement already satisfied: six in c:\users\jimin\anaconda3\lib\site-packages (from knnimpute>=0.1.0->fancyimpute) (1.16.0)
# Requirement already satisfied: numpy>=1.10 in c:\users\jimin\anaconda3\lib\site-packages (from knnimpute>=0.1.0->fancyimpute) (1.20.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\jimin\anaconda3\lib\site-packages (from scikit-learn>=0.24.2->fancyimpute) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jimin\anaconda3\lib\site-packages (from scikit-learn>=0.24.2->fancyimpute) (2.2.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\jimin\anaconda3\lib\site-packages (from scikit-learn>=0.24.2->fancyimpute) (1.7.1)
# Requirement already satisfied: scs>=1.1.6 in c:\users\jimin\anaconda3\lib\site-packages (from cvxpy->fancyimpute) (3.2.2)
# Requirement already satisfied: ecos>=2 in c:\users\jimin\anaconda3\lib\site-packages (from cvxpy->fancyimpute) (2.0.10)
# Requirement already satisfied: osqp>=0.4.1 in c:\users\jimin\anaconda3\lib\site-packages (from cvxpy->fancyimpute) (0.6.2.post8)
# Requirement already satisfied: qdldl in c:\users\jimin\anaconda3\lib\site-packages (from osqp>=0.4.1->cvxpy->fancyimpute) (0.1.5.post2)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\jimin\anaconda3\lib\site-packages (from pytest->fancyimpute) (21.2.0)
# Requirement already satisfied: iniconfig in c:\users\jimin\anaconda3\lib\site-packages (from pytest->fancyimpute) (1.1.1)
# Requirement already satisfied: packaging in c:\users\jimin\anaconda3\lib\site-packages (from pytest->fancyimpute) (21.0)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in c:\users\jimin\anaconda3\lib\site-packages (from pytest->fancyimpute) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in c:\users\jimin\anaconda3\lib\site-packages (from pytest->fancyimpute) (1.10.0)
# Requirement already satisfied: toml in c:\users\jimin\anaconda3\lib\site-packages (from pytest->fancyimpute) (0.10.2)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\jimin\anaconda3\lib\site-packages (from pytest->fancyimpute) (1.4.0)
# Requirement already satisfied: colorama in c:\users\jimin\anaconda3\lib\site-packages (from pytest->fancyimpute) (0.4.4)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\jimin\anaconda3\lib\site-packages (from packaging->pytest->fancyimpute) (3.0.4)

# %% [markdown]
# Load the data into a pandas dataframe.

# %%
#LOAD DATA
import pandas as pd
data = pd.read_csv('customer_data.csv')
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %% [markdown]
# We see there are 18 attributes for each observation and all the variables are quantitative, except for customer ID. It will be important to keep in mind which variables are quantitative, as K-means clustering and PCA require using quantitative variables.

# %%
data.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8950.000000       8950.000000    8950.000000   8949.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8950.000000       8637.000000       8950.000000  8950.000000
# mean    1733.143852        864.206542          0.153715    11.517318
# std     2895.063757       2372.446607          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        169.123707          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        825.485459          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %% [markdown]
# The quantitative variables are on wildly different scales, as some of the variables are pure quantities (balance, purchases, payments), while other variables are frequencies/proportions (balance_frequency, oneoff_purchases). We will need to standardize these variables later prior to clustering to ensure that no variables overpower the distance measure that clustering depends on by arbitrary choice of units/scale.

# %%
#ensure no duplicated entries
data['CUST_ID'].nunique()==len(data)
# Out:
# True

# %%
#get missing values
data.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %% [markdown]
# We see that there are no duplicated entries in the data, but there are some missing values in credit limit and minimum payments. We need to determine how to fill in these missing values, so let's look at the univariate distributions for each of these variables.

# %%
data['MINIMUM_PAYMENTS'].describe()
# Out:
# count     8637.000000
# mean       864.206542
# std       2372.446607
# min          0.019163
# 25%        169.123707
# 50%        312.343947
# 75%        825.485459
# max      76406.207520
# Name: MINIMUM_PAYMENTS, dtype: float64

# %%
data['MINIMUM_PAYMENTS'].plot.hist(alpha=1,bins=25)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['MINIMUM_PAYMENTS'].plot.box()
# Out:
# <AxesSubplot:>

# %%
data['CREDIT_LIMIT'].describe()
# Out:
# count     8949.000000
# mean      4494.449450
# std       3638.815725
# min         50.000000
# 25%       1600.000000
# 50%       3000.000000
# 75%       6500.000000
# max      30000.000000
# Name: CREDIT_LIMIT, dtype: float64

# %%
data['CREDIT_LIMIT'].plot.hist(alpha=1,bins=25)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['CREDIT_LIMIT'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# We see that nearly all the values for minimum payments is less than 10000, but there are some extremely large values. Thus, although only about 3% of the observations have missing values, it is probabily not smart to impute these values with the mean, since the mean will be much larger than most of the observations because of the presence of large values.
#
# The distribution of credit limit is heavily skewed right, so the mean of credit limit is also much larger than most of the observations due to some large values of credit limit. Thus, we will not impute these values with the mean.
#
# Instead, we will impute these values using K-nearest neighbors approach, where the average of the k most "similar" observations will be used to fill in missing values. You can find more about different methods for filling in missing data here (https://towardsdatascience.com/how-to-handle-missing-data-8646b18db0d4).

# %% [markdown]
# For each observation with missing values, we will find the 5 most "similar" observations and set the missing value to be the average those values. The KNN approach for imputation may take some time since there are many attributes, so in general we may not want to use KNN for extremely large dimensional data.

# %%
from fancyimpute import KNN
data_features = data.drop(columns=['CUST_ID']) #remove customer ID for imputation & rest of analysis
data_filled_knn = KNN(k=5).fit_transform(data_features)
final_data = pd.DataFrame(data_filled_knn, columns=data_features.columns)
final_data.isnull().sum()
# Out:
# Imputing row 1/8950 with 0 missing, elapsed time: 43.317
# Imputing row 101/8950 with 0 missing, elapsed time: 43.320
# Imputing row 201/8950 with 0 missing, elapsed time: 43.323
# Imputing row 301/8950 with 0 missing, elapsed time: 43.325
# Imputing row 401/8950 with 0 missing, elapsed time: 43.327
# Imputing row 501/8950 with 0 missing, elapsed time: 43.329
# Imputing row 601/8950 with 0 missing, elapsed time: 43.331
# Imputing row 701/8950 with 0 missing, elapsed time: 43.333
# Imputing row 801/8950 with 0 missing, elapsed time: 43.335
# Imputing row 901/8950 with 0 missing, elapsed time: 43.338
# Imputing row 1001/8950 with 0 missing, elapsed time: 43.341
# Imputing row 1101/8950 with 0 missing, elapsed time: 43.344
# Imputing row 1201/8950 with 0 missing, elapsed time: 43.346
# Imputing row 1301/8950 with 0 missing, elapsed time: 43.347
# Imputing row 1401/8950 with 0 missing, elapsed time: 43.348
# Imputing row 1501/8950 with 0 missing, elapsed time: 43.349
# Imputing row 1601/8950 with 0 missing, elapsed time: 43.352
# Imputing row 1701/8950 with 0 missing, elapsed time: 43.353
# Imputing row 1801/8950 with 0 missing, elapsed time: 43.355
# Imputing row 1901/8950 with 0 missing, elapsed time: 43.356
# Imputing row 2001/8950 with 0 missing, elapsed time: 43.357
# Imputing row 2101/8950 with 0 missing, elapsed time: 43.359
# Imputing row 2201/8950 with 0 missing, elapsed time: 43.360
# Imputing row 2301/8950 with 0 missing, elapsed time: 43.362
# Imputing row 2401/8950 with 0 missing, elapsed time: 43.363
# Imputing row 2501/8950 with 0 missing, elapsed time: 43.364
# Imputing row 2601/8950 with 0 missing, elapsed time: 43.365
# Imputing row 2701/8950 with 0 missing, elapsed time: 43.367
# Imputing row 2801/8950 with 0 missing, elapsed time: 43.369
# Imputing row 2901/8950 with 0 missing, elapsed time: 43.370
# Imputing row 3001/8950 with 0 missing, elapsed time: 43.371
# Imputing row 3101/8950 with 0 missing, elapsed time: 43.373
# Imputing row 3201/8950 with 0 missing, elapsed time: 43.374
# Imputing row 3301/8950 with 0 missing, elapsed time: 43.376
# Imputing row 3401/8950 with 0 missing, elapsed time: 43.377
# Imputing row 3501/8950 with 0 missing, elapsed time: 43.378
# Imputing row 3601/8950 with 0 missing, elapsed time: 43.380
# Imputing row 3701/8950 with 0 missing, elapsed time: 43.382
# Imputing row 3801/8950 with 0 missing, elapsed time: 43.384
# Imputing row 3901/8950 with 0 missing, elapsed time: 43.386
# Imputing row 4001/8950 with 0 missing, elapsed time: 43.387
# Imputing row 4101/8950 with 0 missing, elapsed time: 43.389
# Imputing row 4201/8950 with 0 missing, elapsed time: 43.390
# Imputing row 4301/8950 with 0 missing, elapsed time: 43.390
# Imputing row 4401/8950 with 0 missing, elapsed time: 43.392
# Imputing row 4501/8950 with 0 missing, elapsed time: 43.394
# Imputing row 4601/8950 with 1 missing, elapsed time: 43.395
# Imputing row 4701/8950 with 0 missing, elapsed time: 43.398
# Imputing row 4801/8950 with 1 missing, elapsed time: 43.399
# Imputing row 4901/8950 with 0 missing, elapsed time: 43.401
# Imputing row 5001/8950 with 1 missing, elapsed time: 43.402
# Imputing row 5101/8950 with 0 missing, elapsed time: 43.404
# Imputing row 5201/8950 with 0 missing, elapsed time: 43.406
# Imputing row 5301/8950 with 0 missing, elapsed time: 43.408
# Imputing row 5401/8950 with 0 missing, elapsed time: 43.410
# Imputing row 5501/8950 with 0 missing, elapsed time: 43.413
# Imputing row 5601/8950 with 0 missing, elapsed time: 43.414
# Imputing row 5701/8950 with 0 missing, elapsed time: 43.416
# Imputing row 5801/8950 with 0 missing, elapsed time: 43.419
# Imputing row 5901/8950 with 0 missing, elapsed time: 43.420
# Imputing row 6001/8950 with 0 missing, elapsed time: 43.422
# Imputing row 6101/8950 with 0 missing, elapsed time: 43.424
# Imputing row 6201/8950 with 0 missing, elapsed time: 43.426
# Imputing row 6301/8950 with 0 missing, elapsed time: 43.427
# Imputing row 6401/8950 with 0 missing, elapsed time: 43.430
# Imputing row 6501/8950 with 0 missing, elapsed time: 43.431
# Imputing row 6601/8950 with 0 missing, elapsed time: 43.433
# Imputing row 6701/8950 with 0 missing, elapsed time: 43.435
# Imputing row 6801/8950 with 0 missing, elapsed time: 43.436
# Imputing row 6901/8950 with 0 missing, elapsed time: 43.438
# Imputing row 7001/8950 with 0 missing, elapsed time: 43.439
# Imputing row 7101/8950 with 0 missing, elapsed time: 43.441
# Imputing row 7201/8950 with 0 missing, elapsed time: 43.443
# Imputing row 7301/8950 with 1 missing, elapsed time: 43.444
# Imputing row 7401/8950 with 0 missing, elapsed time: 43.447
# Imputing row 7501/8950 with 0 missing, elapsed time: 43.450
# Imputing row 7601/8950 with 0 missing, elapsed time: 43.452
# Imputing row 7701/8950 with 0 missing, elapsed time: 43.454
# Imputing row 7801/8950 with 1 missing, elapsed time: 43.456
# Imputing row 7901/8950 with 0 missing, elapsed time: 43.457
# Imputing row 8001/8950 with 1 missing, elapsed time: 43.459
# Imputing row 8101/8950 with 0 missing, elapsed time: 43.461
# Imputing row 8201/8950 with 0 missing, elapsed time: 43.463
# Imputing row 8301/8950 with 0 missing, elapsed time: 43.465
# Imputing row 8401/8950 with 1 missing, elapsed time: 43.466
# Imputing row 8501/8950 with 1 missing, elapsed time: 43.469
# Imputing row 8601/8950 with 0 missing, elapsed time: 43.471
# Imputing row 8701/8950 with 0 missing, elapsed time: 43.473
# Imputing row 8801/8950 with 0 missing, elapsed time: 43.475
# Imputing row 8901/8950 with 0 missing, elapsed time: 43.477
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %% [markdown]
# Now that we have filled in the missing values, we will check correlations between variables.

# %%
#see correlation between variables
import matplotlib.pyplot as plt

plt.matshow(final_data.corr())
cb = plt.colorbar()
plt.show()

# %%
final_data.corr()
# Out:
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.322412   0.181261
# BALANCE_FREQUENCY                 0.322412           1.000000   0.133674
# PURCHASES                         0.181261           0.133674   1.000000
# ONEOFF_PURCHASES                  0.164350           0.104323   0.916845
# INSTALLMENTS_PURCHASES            0.126469           0.124292   0.679896
# CASH_ADVANCE                      0.496692           0.099388  -0.051474
# PURCHASES_FREQUENCY              -0.077944           0.229715   0.393017
# ONEOFF_PURCHASES_FREQUENCY        0.073166           0.202415   0.498430
# PURCHASES_INSTALLMENTS_FREQUENCY -0.063186           0.176079   0.315567
# CASH_ADVANCE_FREQUENCY            0.449218           0.191873  -0.120143
# CASH_ADVANCE_TRX                  0.385152           0.141555  -0.067175
# PURCHASES_TRX                     0.154338           0.189626   0.689561
# CREDIT_LIMIT                      0.531305           0.095985   0.356982
# PAYMENTS                          0.322802           0.065008   0.603264
# MINIMUM_PAYMENTS                  0.400127           0.137881   0.094868
# PRC_FULL_PAYMENT                 -0.318959          -0.095082   0.180379
# TENURE                            0.072692           0.119776   0.086288
#
#                                   ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  \
# BALANCE                                   0.164350                0.126469
# BALANCE_FREQUENCY                         0.104323                0.124292
# PURCHASES                                 0.916845                0.679896
# ONEOFF_PURCHASES                          1.000000                0.330622
# INSTALLMENTS_PURCHASES                    0.330622                1.000000
# CASH_ADVANCE                             -0.031326               -0.064244
# PURCHASES_FREQUENCY                       0.264937                0.442418
# ONEOFF_PURCHASES_FREQUENCY                0.524891                0.214042
# PURCHASES_INSTALLMENTS_FREQUENCY          0.127729                0.511351
# CASH_ADVANCE_FREQUENCY                   -0.082628               -0.132318
# CASH_ADVANCE_TRX                         -0.046212               -0.073999
# PURCHASES_TRX                             0.545523                0.628108
# CREDIT_LIMIT                              0.319738                0.256521
# PAYMENTS                                  0.567292                0.384084
# MINIMUM_PAYMENTS                          0.049937                0.132428
# PRC_FULL_PAYMENT                          0.132763                0.182569
# TENURE                                    0.064150                0.086143
#
#                                   CASH_ADVANCE  PURCHASES_FREQUENCY  \
# BALANCE                               0.496692            -0.077944
# BALANCE_FREQUENCY                     0.099388             0.229715
# PURCHASES                            -0.051474             0.393017
# ONEOFF_PURCHASES                     -0.031326             0.264937
# INSTALLMENTS_PURCHASES               -0.064244             0.442418
# CASH_ADVANCE                          1.000000            -0.215507
# PURCHASES_FREQUENCY                  -0.215507             1.000000
# ONEOFF_PURCHASES_FREQUENCY           -0.086754             0.501343
# PURCHASES_INSTALLMENTS_FREQUENCY     -0.177070             0.862934
# CASH_ADVANCE_FREQUENCY                0.628522            -0.308478
# CASH_ADVANCE_TRX                      0.656498            -0.203478
# PURCHASES_TRX                        -0.075850             0.568430
# CREDIT_LIMIT                          0.304001             0.119854
# PAYMENTS                              0.453238             0.103464
# MINIMUM_PAYMENTS                      0.140810             0.005014
# PRC_FULL_PAYMENT                     -0.152935             0.305802
# TENURE                               -0.068312             0.061506
#
#                                   ONEOFF_PURCHASES_FREQUENCY  \
# BALANCE                                             0.073166
# BALANCE_FREQUENCY                                   0.202415
# PURCHASES                                           0.498430
# ONEOFF_PURCHASES                                    0.524891
# INSTALLMENTS_PURCHASES                              0.214042
# CASH_ADVANCE                                       -0.086754
# PURCHASES_FREQUENCY                                 0.501343
# ONEOFF_PURCHASES_FREQUENCY                          1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY                    0.142329
# CASH_ADVANCE_FREQUENCY                             -0.111716
# CASH_ADVANCE_TRX                                   -0.069088
# PURCHASES_TRX                                       0.544869
# CREDIT_LIMIT                                        0.295069
# PAYMENTS                                            0.243537
# MINIMUM_PAYMENTS                                   -0.027354
# PRC_FULL_PAYMENT                                    0.157531
# TENURE                                              0.082466
#
#                                   PURCHASES_INSTALLMENTS_FREQUENCY  \
# BALANCE                                                  -0.063186
# BALANCE_FREQUENCY                                         0.176079
# PURCHASES                                                 0.315567
# ONEOFF_PURCHASES                                          0.127729
# INSTALLMENTS_PURCHASES                                    0.511351
# CASH_ADVANCE                                             -0.177070
# PURCHASES_FREQUENCY                                       0.862934
# ONEOFF_PURCHASES_FREQUENCY                                0.142329
# PURCHASES_INSTALLMENTS_FREQUENCY                          1.000000
# CASH_ADVANCE_FREQUENCY                                   -0.262958
# CASH_ADVANCE_TRX                                         -0.169207
# PURCHASES_TRX                                             0.529975
# CREDIT_LIMIT                                              0.060810
# PAYMENTS                                                  0.085551
# MINIMUM_PAYMENTS                                          0.030825
# PRC_FULL_PAYMENT                                          0.250087
# TENURE                                                    0.073275
#
#                                   CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  \
# BALANCE                                         0.449218          0.385152
# BALANCE_FREQUENCY                               0.191873          0.141555
# PURCHASES                                      -0.120143         -0.067175
# ONEOFF_PURCHASES                               -0.082628         -0.046212
# INSTALLMENTS_PURCHASES                         -0.132318         -0.073999
# CASH_ADVANCE                                    0.628522          0.656498
# PURCHASES_FREQUENCY                            -0.308478         -0.203478
# ONEOFF_PURCHASES_FREQUENCY                     -0.111716         -0.069088
# PURCHASES_INSTALLMENTS_FREQUENCY               -0.262958         -0.169207
# CASH_ADVANCE_FREQUENCY                          1.000000          0.799561
# CASH_ADVANCE_TRX                                0.799561          1.000000
# PURCHASES_TRX                                  -0.131168         -0.066157
# CREDIT_LIMIT                                    0.132603          0.149718
# PAYMENTS                                        0.183192          0.255278
# MINIMUM_PAYMENTS                                0.102853          0.111602
# PRC_FULL_PAYMENT                               -0.249773         -0.169784
# TENURE                                         -0.133372         -0.043421
#
#                                   PURCHASES_TRX  CREDIT_LIMIT  PAYMENTS  \
# BALANCE                                0.154338      0.531305  0.322802
# BALANCE_FREQUENCY                      0.189626      0.095985  0.065008
# PURCHASES                              0.689561      0.356982  0.603264
# ONEOFF_PURCHASES                       0.545523      0.319738  0.567292
# INSTALLMENTS_PURCHASES                 0.628108      0.256521  0.384084
# CASH_ADVANCE                          -0.075850      0.304001  0.453238
# PURCHASES_FREQUENCY                    0.568430      0.119854  0.103464
# ONEOFF_PURCHASES_FREQUENCY             0.544869      0.295069  0.243537
# PURCHASES_INSTALLMENTS_FREQUENCY       0.529975      0.060810  0.085551
# CASH_ADVANCE_FREQUENCY                -0.131168      0.132603  0.183192
# CASH_ADVANCE_TRX                      -0.066157      0.149718  0.255278
# PURCHASES_TRX                          1.000000      0.272910  0.370832
# CREDIT_LIMIT                           0.272910      1.000000  0.421883
# PAYMENTS                               0.370832      0.421883  1.000000
# MINIMUM_PAYMENTS                       0.097759      0.124859  0.126257
# PRC_FULL_PAYMENT                       0.162066      0.055704  0.112138
# TENURE                                 0.121874      0.139296  0.106136
#
#                                   MINIMUM_PAYMENTS  PRC_FULL_PAYMENT    TENURE
# BALANCE                                   0.400127         -0.318959  0.072692
# BALANCE_FREQUENCY                         0.137881         -0.095082  0.119776
# PURCHASES                                 0.094868          0.180379  0.086288
# ONEOFF_PURCHASES                          0.049937          0.132763  0.064150
# INSTALLMENTS_PURCHASES                    0.132428          0.182569  0.086143
# CASH_ADVANCE                              0.140810         -0.152935 -0.068312
# PURCHASES_FREQUENCY                       0.005014          0.305802  0.061506
# ONEOFF_PURCHASES_FREQUENCY               -0.027354          0.157531  0.082466
# PURCHASES_INSTALLMENTS_FREQUENCY          0.030825          0.250087  0.073275
# CASH_ADVANCE_FREQUENCY                    0.102853         -0.249773 -0.133372
# CASH_ADVANCE_TRX                          0.111602         -0.169784 -0.043421
# PURCHASES_TRX                             0.097759          0.162066  0.121874
# CREDIT_LIMIT                              0.124859          0.055704  0.139296
# PAYMENTS                                  0.126257          0.112138  0.106136
# MINIMUM_PAYMENTS                          1.000000         -0.136042  0.060731
# PRC_FULL_PAYMENT                         -0.136042          1.000000 -0.016486
# TENURE                                    0.060731         -0.016486  1.000000

# %% [markdown]
# Overall, the variables do not seem to be highly correlated with each other. The purchase variables seem to be highly correlated with each other (purchases, oneoff_purchases, installments_purchases, purchases_trx). Similarly, the cash variables (cash_advance, cash_advance_frequency, cash_advance_trx) are highly correlated with one another.

# %% [markdown]
# We will standardize the data.
#
# K-Means calculates a distance measure between observations, so to prevent any variables from dominating the distance measure due to arbitrary choice of scale, standardizing is important.
#
# Additionally, PCA is sensitive to the scale of the features, as each principal component is a linear combination of the original variables that seeks to retain the maximum variance in the original data. Thus, variables with large units will tend to dominate the first PCs as they will likely have the largest variances, so standardizing is important for computating PCs.

# %%
#STANDARDIZE DATA PRIOR TO CLUSTERING
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(final_data.values)

# %% [markdown]
# Visualize the data on the first 2 PCs to see if there are any noticable cluster patterns prior to performing formal clustering analysis.

# %%
from sklearn.decomposition import PCA

# PCA w/ 2 components
pca_2d = PCA(n_components=2)
pc_2d = pca_2d.fit_transform(scaled_data)
# create dataframe
pca_2d_df = pd.DataFrame(data = pc_2d, columns =['pca1','pca2'])

import seaborn as sns
plt.figure(figsize=(10,10))
ax = sns.scatterplot(x="pca1", y="pca2", data = pca_2d_df)
plt.show()

# %% [markdown]
# There does not seem to be any clear partitioning in the data, a vast majority of the data seems to be within the range of 0-5 for both pca1 and pca2.
#
# We will proceed with K-means clustering.

# %% [markdown]
# K-Means clustering algorithm iterates as follows:
#
# 1) Initialize k centroids.
#
# 2) Repeat the following until stopping criteria satisfied - predetermined number of iterations or until cluster labels stop changing.
#
#     - Assign each point to the label of the centroid it is closest to
#     - Move each centroid to the mean of all of its labeled points
#
# More information about K-Means clustering can be found here (https://stanford.edu/~cpiech/cs221/handouts/kmeans.html).

# %% [markdown]
# However, at this stage we don't know the number of optimal clusters to partition our data.
#
# - Thus, we will perform k-means clustering for a range of values of k, in this case 1-20
# - We will select the k-value where Within Cluster Sum of Squares (WCSS) seems to start decreasing at a slower rate, a.k.a the elbow method
#
# Additionally, the result produced by K-Means can vary a lot depending on how the centroids are initialized, as an unlucky initialization can lead to less than ideal clustering.
#
# - For each value of k, we will perform multiple iterations of the algorithm (n_init=10) to reduce the chance of landing on a local optimum
# - We will use k-means++ method to initialize centroids -> first centroid is randomly initialized, and then the probability of any given point in the variable space to be selected as the location of the next centroid is proportional to the square of the point's distance to the closest existing centroid. The end result is that centroids are most likely to be spread apart.
#
# More information about different centroid initialization methods can be found here (https://www.kdnuggets.com/2020/06/centroid-initialization-k-means-clustering.html).

# %%
#iterate through different number of clusters to find ideal value of K
from sklearn.cluster import KMeans

wcss = []
for i in range(1, 21):
    kmeans = KMeans(init='k-means++',
                    n_clusters=i,
                    n_init=10,
                    max_iter=300,
                    algorithm='auto')
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1,21), wcss)
plt.title('WCSS by Clusters (K-means++ Centroid Initialization)')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# Although it is hard to tell, it seems that WCSS starts to decrease at a slower rate starting at 4 or 5 clusters.

# %%
from kneed import KneeLocator
kl = KneeLocator(
    range(1, 21), wcss, curve="convex", direction="decreasing"
)

kl.elbow
# Out:
# 6

# %% [markdown]
# The kneed package suggests otherwise - it suggests that the elbow point in the plot is at 6 clusters.

# %% [markdown]
# Silhouette scores are also another metric for evaluating the quality of a clustering solution. Silhouette scores can range from [-1, 1] where numbers close to 1 indicate clearly distinguishable clusters, values close to 0 indicate no cluster structure is evident, and values close to -1 indicate cluster assignments are incorrect.

# %%
from sklearn.metrics import silhouette_score
# A list holds the silhouette coefficients for each k
silhouette_coefficients = []

# Notice you start at 2 clusters for silhouette coefficient
for k in range(2, 21):
    kmeans = KMeans(init='k-means++',
                    n_clusters=i,
                    n_init=10,
                    max_iter=300,
                    algorithm='auto')
    kmeans.fit(scaled_data)
    score = silhouette_score(scaled_data, kmeans.labels_)
    silhouette_coefficients.append(score)
    
plt.plot(range(2,21), silhouette_coefficients)
plt.title('Silhouette Coefficients by Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Coefficients')
plt.show()

# %%
silhouette_coefficients
# Out:
# [0.20609880746408565,
#  0.2065696518088616,
#  0.20789598788505417,
#  0.21401060012438475,
#  0.21377267120184304,
#  0.2075399885084977,
#  0.21400212223170853,
#  0.2129956214370723,
#  0.17727716130572616,
#  0.17506632713164738,
#  0.22164268277773308,
#  0.20564685890901688,
#  0.17671321678173546,
#  0.17627546790874388,
#  0.20631535409578142,
#  0.20630462737728894,
#  0.20380904634790378,
#  0.1969112198990393,
#  0.1703872444780458]

# %%
max(silhouette_coefficients)-min(silhouette_coefficients)
# Out:
# 0.05125543829968729

# %% [markdown]
# Silhouette plot indicates that clustering solutions with 5, 6, or 12 clusters have relatively high silhoutte values.
# However, the scale of the plot seems to exaggerate the small differences in silhouette coefficient values, as they are all within 0.06 of each other.
#
# We will proceed with 5 clusters as it has a relatively high silhouette coefficient and it seems to be around where WCSS starts to decrease at a slower rate. Additionally, we want to minimize the number of clusters if we can to make interpreting our clustering solution easier.

# %%
#Proceed with 5 clusters
kmeans_sol = KMeans(init='k-means++',
                    n_clusters=5,
                    n_init=10,
                    max_iter=300,
                    algorithm='auto')
kmeans_sol.fit(scaled_data)
# cluster_data = pd.DataFrame(data=kmeans_sol.cluster_centers_, columns = [final_data.columns])
# cluster_data
# Out:
# KMeans(n_clusters=5)

# %% [markdown]
# Add the cluster labels to our original dataset so we can visualize cluster groups.

# %%
#add cluster assignments to dataset
data["CLUSTER_NUMBER"] = pd.Series(kmeans_sol.labels_).values

# %%
data["CLUSTER_NUMBER"].value_counts()
# Out:
# 0    3917
# 2    2417
# 3    1387
# 4    1147
# 1      82
# Name: CLUSTER_NUMBER, dtype: int64

# %% [markdown]
# We see that there are cluster 0 is the largest cluster with 3917 observations, whereas cluster 1 is extremely small compared to the other clusters with only 82 observations.

# %%
by_cluster = data.groupby("CLUSTER_NUMBER")

# %%
by_cluster.mean()
# Out:
#                     BALANCE  BALANCE_FREQUENCY     PURCHASES  \
# CLUSTER_NUMBER
# 0               1054.158129           0.797186    278.816885
# 1               4501.309782           0.975499  16124.096585
# 2                641.890264           0.902038    793.897729
# 3               1912.509755           0.979515   2946.591384
# 4               4620.492692           0.967908    487.017036
#
#                 ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  CASH_ADVANCE  \
# CLUSTER_NUMBER
# 0                     226.024547               52.994452    621.879682
# 1                   10943.910122             5180.186463   1053.988646
# 2                     167.020190              627.371241    177.417996
# 3                    1998.920252              948.103720    360.865848
# 4                     299.377071              187.728605   4628.793763
#
#                 PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY  \
# CLUSTER_NUMBER
# 0                          0.163416                    0.097199
# 1                          0.926626                    0.766778
# 2                          0.855715                    0.083816
# 3                          0.924633                    0.732595
# 4                          0.280580                    0.130514
#
#                 PURCHASES_INSTALLMENTS_FREQUENCY  CASH_ADVANCE_FREQUENCY  \
# CLUSTER_NUMBER
# 0                                       0.065477                0.119003
# 1                                       0.779989                0.085366
# 2                                       0.792908                0.037931
# 3                                       0.588411                0.058667
# 4                                       0.181951                0.491157
#
#                 CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT      PAYMENTS  \
# CLUSTER_NUMBER
# 0                       2.214705       2.955578   3344.731797   1006.259893
# 1                       2.939024     132.548780  12358.536585  15866.407213
# 2                       0.707075      16.616880   3197.023713    932.496685
# 3                       1.173035      43.722422   7008.289310   2805.018482
# 4                      14.668701       7.324324   7552.663074   3596.047916
#
#                 MINIMUM_PAYMENTS  PRC_FULL_PAYMENT     TENURE
# CLUSTER_NUMBER
# 0                     590.987767          0.070322  11.454685
# 1                    3400.127002          0.396699  11.963415
# 2                     678.425198          0.272348  11.455523
# 3                     848.962907          0.265434  11.883922
# 4                    2025.870794          0.036046  11.386225

# %% [markdown]
# We will plot the distribution of each variable by cluster group to see on which attributes do the clusters differ.

# %%
# Plot the histogram of various clusters
for i in final_data.columns:
  plt.figure(figsize = (35, 5))
  for j in range(5):
    plt.subplot(1,5,j+1)
    cluster = data[data['CLUSTER_NUMBER'] == j]
    cluster[i].hist(bins = 20)
    plt.title('{}    \nCluster {} '.format(i,j))
  
  plt.show()

# %% [markdown]
# Some key takeaways:
# - Cluster 1 has high balance, purchases, credit limit
# - Cluster 3 has low balance and fairly high credit limit -> these customers have good credit score, likely to pay back money they spend
# - Cluster 4 has high balance, cash advance, low percent of full payment -> they don't pay their cash back in full and they have highest outstanding balance, so people in cluster 4 are typically those who the bank can profit the most off of

# %% [markdown]
# We will perform PCA and extract the first 2 principal components to visualize the clusters.

# %%
from sklearn.decomposition import PCA

# PCA w/ 2 components
pca_2d = PCA(n_components=2)
pc_2d = pca_2d.fit_transform(scaled_data)
# create dataframe
pca_2d_df = pd.DataFrame(data = pc_2d, columns =['pca1','pca2'])
# add cluster labels to dataframe
pca_2d_df = pd.concat([pca_2d_df, pd.DataFrame({'cluster':kmeans_sol.labels_})], axis = 1)
pca_2d_df.head()
# Out:
#        pca1      pca2  cluster
# 0 -1.683480 -1.072790        0
# 1 -1.134802  2.507546        4
# 2  0.969507 -0.383352        3
# 3 -0.886063  0.009608        0
# 4 -1.599858 -0.684002        0

# %%
#PCA WEIGHTS
pca_2d.components_
# Out:
# array([[ 0.10168769,  0.12058996,  0.41157404,  0.3463541 ,  0.33675183,
#         -0.02287032,  0.32127062,  0.29453695,  0.27451736, -0.08860612,
#         -0.0481834 ,  0.39061504,  0.21187888,  0.26642595,  0.06258296,
#          0.1318689 ,  0.08110242],
#        [ 0.40395079,  0.13185203,  0.04004915,  0.06193291, -0.01914535,
#          0.43885742, -0.19101556, -0.01848196, -0.17875498,  0.43408173,
#          0.41950876, -0.02008753,  0.23789023,  0.25650052,  0.16999761,
#         -0.19009548, -0.0041368 ]])

# %% [markdown]
# Above we have the components of the first 2 PCAs - each component has 17 weights, one for each variable.
#
# From these numerical components, we can make some inferences about what high values in either of the PCs mean.
#
# Observations with high values for PCA 1 -> large number of purchases, purchase transactions.
#
# Observations with high values for PCA 2 -> large outstanding balance, cash in advance, low purchase frequency, low percent of full payment.

# %%
import seaborn as sns
plt.figure(figsize=(10,10))
ax = sns.scatterplot(x="pca1", y="pca2", hue = "cluster", data = pca_2d_df, palette =['red','green','blue','pink', 'orange'])
plt.show()
